# %% [markdown]
# # QuickUMLS ini analysis

# %%
import pandas as pd
import json
from quickumls import QuickUMLS
import ast

# %% [markdown]
# Load QuickUMLS and semtype dictionary searcher run NER. Run under WSL since quickumls installation works better on linux. Takes around 30s

# %%
quickumls_db = "/mnt/c/Users/maxji/.data/bio/quickUMLS" #root folder where quickumls is downloaded

matcher = QuickUMLS(
    quickumls_db,
    threshold=0.7,
    similarity_name='jaccard'
)

# %% [markdown]
# loading initialization

# %%
mrsty_path = "/mnt/c/Users/maxji/.data/bio/umls/2025AA/umls-2025AA-metathesaurus-full/2025AA/META/MRSTY.RRF"
def load_semtype_labels(mrsty_path):
    df = pd.read_csv(
        mrsty_path,
        sep='|',
        header=None,
        dtype=str,
        engine='python'
    )
    # Drop the last empty column if present
    if df.shape[1] > 6:
        df = df.iloc[:, :6]
    df.columns = ['CUI', 'TUI', 'STN', 'STY', 'ATUI', 'CVF']
    df = df[['TUI', 'STY']].drop_duplicates()
    return dict(zip(df['TUI'], df['STY']))
# Example usage
semtype_dict = load_semtype_labels(mrsty_path)
print(semtype_dict['T047'])  # Disease or Syndrome
# Out:
# Disease or Syndrome

# %% [markdown]
# # Part 1: reading in our past dataset

# %%
df_mini_pairs = pd.read_csv("english-train-paired-conversations.csv")
print("data length:", len(df_mini_pairs)) 
df_mini_pairs.head(n=5)
# Out:
# data length: 480
#    Unnamed: 0                                        description  \
# 0           0  throat a bit sore and want to get a good imune...
# 1           1  hey there i have had cold "symptoms" for over ...
# 2           2  i have a tight and painful chest with a dry co...
# 3           3  what will happen after the incubation period f...
# 4           4                    suggest treatment for pneumonia
#
#                                           utterances
# 0  ['patient: throat a bit sore and want to get a...
# 1  ['patient: hey there i have had cold "symptoms...
# 2  ['patient: i have a tight and painful chest wi...
# 3  ['patient: what will happen after the incubati...
# 4  ['patient: just found out i was pregnant. yest...

# %% [markdown]
# convert the utterances to a list

# %%
#currently, each one is being interpreted as a string instread of a list
print(len(df_mini_pairs["utterances"][0]))
df_mini_pairs['utterances'] = df_mini_pairs['utterances'].apply(ast.literal_eval)
print(len(df_mini_pairs["utterances"][0]))
# Out:
# 603
# 2

# %% [markdown]
# # Using the QuickUMLS model on a single data sample, data format

# %% [markdown]
# Testing data on a single datapoint.
#
# Split based on last : found

# %%
#
index = 0
patient = df_mini_pairs.iloc[index]["utterances"][0].replace("patient:","").strip() #raw patient string replacing doctor, patient
clinician = df_mini_pairs.iloc[index]["utterances"][1].replace("doctor:","").strip() #raw clinican stinrg
print(patient,"\n",clinician)
# Out:
# throat a bit sore and want to get a good imune booster, especially in light of the virus. please advise. have not been in contact with nyone with the virus.
#  during this pandemic. throat pain can be from a strep throat infection (antibiotics needed), a cold or influenza or other virus, or from some other cause such as allergies or irritants. usually, a person sees the doctor (call first) if the sore throat is bothersome, recurrent, or doesn't go away quickly. covid-19 infections tend to have cough, whereas strep throat usually lacks cough but has more throat pain. (3/21/20)

# %%
matches = matcher.match(patient, best_match=True, ignore_syntax=False)
for x in matches:
    #output all matches
    for final in x:
        print("term:", final["term"])
        semtypes_list = list(final["semtypes"])
        print("semtypes:", semtypes_list) #convert 
        #now, convert semtypes to codes using the dictionary matcher
        semtypes_matches = []
        for type in semtypes_list:
            semtypes_matches.append(semtype_dict[type])
        print("semtype matches:", semtypes_matches)
        print(final)
# Out:
# term: booster
# semtypes: ['T061']
# semtype matches: ['Therapeutic or Preventive Procedure']
# {'start': 47, 'end': 54, 'ngram': 'booster', 'term': 'booster', 'cui': 'C0020975', 'similarity': 1.0, 'semtypes': {'T061'}, 'preferred': 1}
# term: contact
# semtypes: ['T067']
# semtype matches: ['Phenomenon or Process']
# {'start': 122, 'end': 129, 'ngram': 'contact', 'term': 'contact', 'cui': 'C0392367', 'similarity': 1.0, 'semtypes': {'T067'}, 'preferred': 1}
# term: contact
# semtypes: ['T170']
# semtype matches: ['Intellectual Product']
# {'start': 122, 'end': 129, 'ngram': 'contact', 'term': 'contact', 'cui': 'C3245509', 'similarity': 1.0, 'semtypes': {'T170'}, 'preferred': 1}
# term: throat
# semtypes: ['T023']
# semtype matches: ['Body Part, Organ, or Organ Component']
# {'start': 0, 'end': 6, 'ngram': 'throat', 'term': 'throat', 'cui': 'C3665375', 'similarity': 1.0, 'semtypes': {'T023'}, 'preferred': 1}
# term: throats
# semtypes: ['T023']
# semtype matches: ['Body Part, Organ, or Organ Component']
# {'start': 0, 'end': 6, 'ngram': 'throat', 'term': 'throats', 'cui': 'C0031354', 'similarity': 0.8, 'semtypes': {'T023'}, 'preferred': 1}
# term: throat
# semtypes: ['T023']
# semtype matches: ['Body Part, Organ, or Organ Component']
# {'start': 0, 'end': 6, 'ngram': 'throat', 'term': 'throat', 'cui': 'C0031354', 'similarity': 1.0, 'semtypes': {'T023'}, 'preferred': 0}
# term: virus
# semtypes: ['T047']
# semtype matches: ['Disease or Syndrome']
# {'start': 83, 'end': 88, 'ngram': 'virus', 'term': 'virus', 'cui': 'C0042769', 'similarity': 1.0, 'semtypes': {'T047'}, 'preferred': 1}
# term: virus
# semtypes: ['T047']
# semtype matches: ['Disease or Syndrome']
# {'start': 150, 'end': 155, 'ngram': 'virus', 'term': 'virus', 'cui': 'C0042769', 'similarity': 1.0, 'semtypes': {'T047'}, 'preferred': 1}
# term: sore
# semtypes: ['T184']
# semtype matches: ['Sign or Symptom']
# {'start': 13, 'end': 17, 'ngram': 'sore', 'term': 'sore', 'cui': 'C0234233', 'similarity': 1.0, 'semtypes': {'T184'}, 'preferred': 1}
# term: blight
# semtypes: ['T047']
# semtype matches: ['Disease or Syndrome']
# {'start': 70, 'end': 75, 'ngram': 'light', 'term': 'blight', 'cui': 'C0275586', 'similarity': 0.75, 'semtypes': {'T047'}, 'preferred': 1}
# term: flight
# semtypes: ['T067']
# semtype matches: ['Phenomenon or Process']
# {'start': 70, 'end': 75, 'ngram': 'light', 'term': 'flight', 'cui': 'C2610507', 'similarity': 0.75, 'semtypes': {'T067'}, 'preferred': 1}
# term: Slight
# semtypes: ['T033']
# semtype matches: ['Finding']
# {'start': 70, 'end': 75, 'ngram': 'light', 'term': 'Slight', 'cui': 'C5202796', 'similarity': 0.75, 'semtypes': {'T033'}, 'preferred': 1}

# %% [markdown]
# Creating a generalized function to help find matches

# %%
#returns a dictionary of terms to a tuple of semtype_list and matched terms_list with the same length

def quickumls_matcher(text):
    matches = matcher.match(text, best_match=True, ignore_syntax=False)
    terms_dictionary = {}
    for x in matches:
        #output all matches
        for final in x:
            semtypes_list = list(final["semtypes"])
            #now, convert semtypes to codes using the dictionary matcher
            semtypes_matches = []
            for type in semtypes_list:
                semtypes_matches.append(semtype_dict[type])
            terms_dictionary[final["term"]] = (semtypes_list, semtypes_matches)
    return terms_dictionary

# %%
text = "The patient was given aspirin for pain relief."
clinician_entity_dict = {}
terms_dictionary = quickumls_matcher(clinician)
print(terms_dictionary)
for term in terms_dictionary: #each term is a key
    data = terms_dictionary[term]
    semtypes_list = data[0]
    semtypes_matches = data[1]
    print("\n____________________________________________________\n")
# Out:
# {'throat infection': (['T047'], ['Disease or Syndrome']), 'strep throat': (['T047'], ['Disease or Syndrome']), 'throat pain': (['T184'], ['Sign or Symptom']), 'Throat pain': (['T184'], ['Sign or Symptom']), 'sore throat': (['T184'], ['Sign or Symptom']), 'No sore throat': (['T033'], ['Finding']), 'infections': (['T046'], ['Pathologic Function']), 'infection': (['T047'], ['Disease or Syndrome']), 'Reinfections': (['T046'], ['Pathologic Function']), 'Coinfections': (['T047'], ['Disease or Syndrome']), 'Infections': (['T046'], ['Pathologic Function']), 'Re-infections': (['T046'], ['Pathologic Function']), 'Co-infections': (['T047'], ['Disease or Syndrome']), 'infections op': (['T047'], ['Disease or Syndrome']), 'gi infections': (['T047'], ['Disease or Syndrome']), 'Reinfection': (['T046'], ['Pathologic Function']), 'Coinfection': (['T047'], ['Disease or Syndrome']), 'influenza': (['T047'], ['Disease or Syndrome']), 'influenza B': (['T047'], ['Disease or Syndrome']), 'influenza C': (['T047'], ['Disease or Syndrome']), 'influenza A': (['T047'], ['Disease or Syndrome']), 'allergies': (['T046'], ['Pathologic Function']), 'Allergies': (['T201'], ['Clinical Attribute']), 'pandemic': (['T067'], ['Phenomenon or Process']), 'virus': (['T047'], ['Disease or Syndrome']), 'cold': (['T047'], ['Disease or Syndrome']), 'sees': (['T040'], ['Organism Function']), 'Antibiotics': (['T195'], ['Antibiotic']), 'antibiotic Y': (['T195'], ['Antibiotic']), 'antibiotics': (['T195'], ['Antibiotic']), 'antibiotic': (['T195'], ['Antibiotic']), 'coughs': (['T033'], ['Finding']), 'cough': (['T184'], ['Sign or Symptom'])}
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________
#
#
# ____________________________________________________

# %% [markdown]
# # Finding Entities: Analyzing through the mini data using QuickUMLS

# %% [markdown]
# Finding the entity_groups found for both patient and clinician data, and the count of mapped entities for each patient category

# %%
patient_entity_dict = {}
clinician_entity_dict = {}
for index,row in df_mini_pairs.iterrows():
    utterances = row["utterances"]
    
    try:  
        patient =  utterances[0].replace("patient:","").strip()
        terms_dictionary = quickumls_matcher(patient)
        #loop through the entities. Each term is a key
        for term in terms_dictionary:
            data = terms_dictionary[term]
            semtypes_list = data[0]
            semtypes_matches = data[1]
            #then, loop through the matches 
            for match in semtypes_matches:
                if match not in patient_entity_dict:
                    patient_entity_dict[match] = 1
                else:
                    patient_entity_dict[match] += 1
    except Exception as e:
        print(f"An error occurred in patient data: {e}")
        pass

    try: 
        clinician = utterances[1].replace("doctor:","").strip()
        terms_dictionary = quickumls_matcher(clinician)
        for term in terms_dictionary:
            data = terms_dictionary[term]
            semtypes_list = data[0]
            semtypes_matches = data[1]
            #then, loop through the matches 
            for match in semtypes_matches:
                if match not in clinician_entity_dict:
                    clinician_entity_dict[match] = 1
                else:
                    clinician_entity_dict[match] += 1
    except Exception as e:
        print(f"An error occurred in clinican data: {e}")
        pass

# %% [markdown]
# Analyzing the set of patient entity

# %%
print(patient_entity_dict)
# Out:
# {'Therapeutic or Preventive Procedure': 273, 'Intellectual Product': 563, 'Body Part, Organ, or Organ Component': 381, 'Disease or Syndrome': 862, 'Sign or Symptom': 866, 'Phenomenon or Process': 53, 'Finding': 1152, 'Organism Function': 109, 'Body Location or Region': 116, 'Laboratory or Test Result': 42, 'Laboratory Procedure': 41, 'Diagnostic Procedure': 84, 'Pharmacologic Substance': 339, 'Hormone': 11, 'Organic Chemical': 255, 'Medical Device': 117, 'Inorganic Chemical': 9, 'Mental or Behavioral Dysfunction': 50, 'Vitamin': 17, 'Mental Process': 187, 'Pathologic Function': 114, 'Health Care Activity': 237, 'Amino Acid, Peptide, or Protein': 22, 'Antibiotic': 205, 'Body Substance': 61, 'Physiologic Function': 40, 'Clinical Attribute': 82, 'Indicator, Reagent, or Diagnostic Aid': 25, 'Immunologic Factor': 23, 'Injury or Poisoning': 41, 'Neoplastic Process': 10, 'Hazardous or Poisonous Substance': 1, 'Clinical Drug': 22, 'Biologically Active Substance': 4, 'Element, Ion, or Isotope': 1, 'Nucleic Acid, Nucleoside, or Nucleotide': 6, 'Congenital Abnormality': 2}

# %%
print(clinician_entity_dict)
# Out:
# {'Disease or Syndrome': 1662, 'Sign or Symptom': 714, 'Finding': 1711, 'Pathologic Function': 522, 'Clinical Attribute': 191, 'Phenomenon or Process': 72, 'Organism Function': 159, 'Antibiotic': 227, 'Intellectual Product': 1236, 'Body Substance': 69, 'Neoplastic Process': 21, 'Mental Process': 504, 'Mental or Behavioral Dysfunction': 37, 'Pharmacologic Substance': 867, 'Hormone': 35, 'Amino Acid, Peptide, or Protein': 33, 'Therapeutic or Preventive Procedure': 562, 'Diagnostic Procedure': 116, 'Health Care Activity': 646, 'Organic Chemical': 419, 'Body Part, Organ, or Organ Component': 286, 'Vitamin': 30, 'Laboratory Procedure': 98, 'Inorganic Chemical': 38, 'Medical Device': 209, 'Physiologic Function': 57, 'Immunologic Factor': 50, 'Injury or Poisoning': 72, 'Body Location or Region': 65, 'Hazardous or Poisonous Substance': 10, 'Indicator, Reagent, or Diagnostic Aid': 42, 'Biologically Active Substance': 10, 'Clinical Drug': 11, 'Laboratory or Test Result': 56, 'Element, Ion, or Isotope': 5, 'Nucleic Acid, Nucleoside, or Nucleotide': 21, 'Food': 1, 'Manufactured Object': 4}

# %% [markdown]
# Finding the sum of values in total

# %%
print("number of patient data:", sum(patient_entity_dict.values()))
print("number of clinican data:", sum(clinician_entity_dict.values()))
# Out:
# number of patient data: 6423
# number of clinican data: 10868

# %% [markdown]
# Number of unique values in the keys

# %%
print( "number of unique patient entites:", len(set(patient_entity_dict.keys())) )
# Out:
# number of unique patient entites: 37

# %%
print( "number of unique clinican entites:", len(set(clinician_entity_dict.keys())) )
# Out:
# number of unique clinican entites: 38

# %% [markdown]
# Number of clinican entities is similar, with the only difference being:

# %%
set(clinician_entity_dict.keys()) - set(patient_entity_dict.keys())
# Out:
# {'Food', 'Manufactured Object'}

# %% [markdown]
# Sorting based on values

# %%
patient_entity_dict_sorted = sorted(patient_entity_dict.items(), key=lambda  item: item[1], reverse=True)
patient_entity_dict_sorted
# Out:
# [('Finding', 1152),
#  ('Sign or Symptom', 866),
#  ('Disease or Syndrome', 862),
#  ('Intellectual Product', 563),
#  ('Body Part, Organ, or Organ Component', 381),
#  ('Pharmacologic Substance', 339),
#  ('Therapeutic or Preventive Procedure', 273),
#  ('Organic Chemical', 255),
#  ('Health Care Activity', 237),
#  ('Antibiotic', 205),
#  ('Mental Process', 187),
#  ('Medical Device', 117),
#  ('Body Location or Region', 116),
#  ('Pathologic Function', 114),
#  ('Organism Function', 109),
#  ('Diagnostic Procedure', 84),
#  ('Clinical Attribute', 82),
#  ('Body Substance', 61),
#  ('Phenomenon or Process', 53),
#  ('Mental or Behavioral Dysfunction', 50),
#  ('Laboratory or Test Result', 42),
#  ('Laboratory Procedure', 41),
#  ('Injury or Poisoning', 41),
#  ('Physiologic Function', 40),
#  ('Indicator, Reagent, or Diagnostic Aid', 25),
#  ('Immunologic Factor', 23),
#  ('Amino Acid, Peptide, or Protein', 22),
#  ('Clinical Drug', 22),
#  ('Vitamin', 17),
#  ('Hormone', 11),
#  ('Neoplastic Process', 10),
#  ('Inorganic Chemical', 9),
#  ('Nucleic Acid, Nucleoside, or Nucleotide', 6),
#  ('Biologically Active Substance', 4),
#  ('Congenital Abnormality', 2),
#  ('Hazardous or Poisonous Substance', 1),
#  ('Element, Ion, or Isotope', 1)]

# %%
clinican_entity_dict_sorted = sorted(clinician_entity_dict.items(), key=lambda  item: item[1], reverse=True)
clinican_entity_dict_sorted
# Out:
# [('Finding', 1711),
#  ('Disease or Syndrome', 1662),
#  ('Intellectual Product', 1236),
#  ('Pharmacologic Substance', 867),
#  ('Sign or Symptom', 714),
#  ('Health Care Activity', 646),
#  ('Therapeutic or Preventive Procedure', 562),
#  ('Pathologic Function', 522),
#  ('Mental Process', 504),
#  ('Organic Chemical', 419),
#  ('Body Part, Organ, or Organ Component', 286),
#  ('Antibiotic', 227),
#  ('Medical Device', 209),
#  ('Clinical Attribute', 191),
#  ('Organism Function', 159),
#  ('Diagnostic Procedure', 116),
#  ('Laboratory Procedure', 98),
#  ('Phenomenon or Process', 72),
#  ('Injury or Poisoning', 72),
#  ('Body Substance', 69),
#  ('Body Location or Region', 65),
#  ('Physiologic Function', 57),
#  ('Laboratory or Test Result', 56),
#  ('Immunologic Factor', 50),
#  ('Indicator, Reagent, or Diagnostic Aid', 42),
#  ('Inorganic Chemical', 38),
#  ('Mental or Behavioral Dysfunction', 37),
#  ('Hormone', 35),
#  ('Amino Acid, Peptide, or Protein', 33),
#  ('Vitamin', 30),
#  ('Neoplastic Process', 21),
#  ('Nucleic Acid, Nucleoside, or Nucleotide', 21),
#  ('Clinical Drug', 11),
#  ('Hazardous or Poisonous Substance', 10),
#  ('Biologically Active Substance', 10),
#  ('Element, Ion, or Isotope', 5),
#  ('Manufactured Object', 4),
#  ('Food', 1)]

# %% [markdown]
# Finding the set differences

# %%
set(patient_entity_dict.keys()).difference(set(clinician_entity_dict.keys()))
# Out:
# {'Congenital Abnormality'}

# %%
set(clinician_entity_dict.keys()).difference(set(patient_entity_dict.keys()))
# Out:
# {'Food', 'Manufactured Object'}

# %% [markdown]
# We can see that there are few mappings. Additionally, we

# %% [markdown]
# # Finding entity mismatches: looping through the minidata to find mismatches between entities the paired data

# %% [markdown]
# Now, we can perform a different type of analysis. Now, that we know that there is a discrepancy between total values, what are differences in the occurance per dialogue. We use the list of found entities before

# %%
clinician_entity_dict.keys()
# Out:
# dict_keys(['Disease or Syndrome', 'Sign or Symptom', 'Finding', 'Pathologic Function', 'Clinical Attribute', 'Phenomenon or Process', 'Organism Function', 'Antibiotic', 'Intellectual Product', 'Body Substance', 'Neoplastic Process', 'Mental Process', 'Mental or Behavioral Dysfunction', 'Pharmacologic Substance', 'Hormone', 'Amino Acid, Peptide, or Protein', 'Therapeutic or Preventive Procedure', 'Diagnostic Procedure', 'Health Care Activity', 'Organic Chemical', 'Body Part, Organ, or Organ Component', 'Vitamin', 'Laboratory Procedure', 'Inorganic Chemical', 'Medical Device', 'Physiologic Function', 'Immunologic Factor', 'Injury or Poisoning', 'Body Location or Region', 'Hazardous or Poisonous Substance', 'Indicator, Reagent, or Diagnostic Aid', 'Biologically Active Substance', 'Clinical Drug', 'Laboratory or Test Result', 'Element, Ion, or Isotope', 'Nucleic Acid, Nucleoside, or Nucleotide', 'Food', 'Manufactured Object'])

# %%
#initialize a dictionary of mismatches 
patient_mismatch_dict = {} #entities mapped in patient text but not in the clinican text
clinician_mismatch_dict = {}  #entities mapped in clinican text but not in the patient text
for key in list(patient_entity_dict.keys()):
    patient_mismatch_dict[key] = 0
for key in list(clinician_entity_dict.keys()):
    clinician_mismatch_dict[key] = 0

# %%
#track the row indices with a patient mismatch mapping diex w
patient_mismatch_rows = []
#track the rows with a  clinican mismatch
clinician_mismatch_rows = []

for index,row in df_mini_pairs.iterrows():
    current_patient_entities = set()
    current_clinican_entities = set()
    utterances = row["utterances"]
    
    try:  
        patient =  utterances[0].replace("patient:","").strip()
        terms_dictionary = quickumls_matcher(patient)
        #loop through the entities. Each term is a key
        for term in terms_dictionary:
            data = terms_dictionary[term]
            semtypes_list = data[0]
            semtypes_matches = data[1]
            #add matches to the set
            current_patient_entities.update(semtypes_matches)

    except Exception as e:
        print(f"An error occurred in patient data: {e}")
        pass

    try: 
        clinician = utterances[1].replace("doctor:","").strip()
        terms_dictionary = quickumls_matcher(clinician)
        for term in terms_dictionary:
            data = terms_dictionary[term]
            semtypes_list = data[0]
            semtypes_matches = data[1]
            #add matches to the set 
            current_clinican_entities.update(semtypes_matches)

    except:
        print("no clinican mapping at index:", index)
        pass 
    #find mismatches by computing set differneces 
    #entities mapped in patient text but not in the clinican text. increment the dictionary of mismatches 
    patient_mismatch = current_patient_entities - current_clinican_entities
    if len(patient_mismatch) > 0:
        patient_mismatch_rows.append(index) #if the number of mismatches is non zero, append
    for key in patient_mismatch:
        patient_mismatch_dict[key] += 1

    clinician_mismatch = current_clinican_entities - current_patient_entities
    if len(clinician_mismatch) > 0:
        clinician_mismatch_rows.append(index) #if the number of mismatches is non zero, append
    for key in clinician_mismatch:
        clinician_mismatch_dict[key] += 1

# %% [markdown]
# Printing sums of total mismatches

# %%
print("number of patient data:", sum(patient_mismatch_dict.values()))
print("number of clinician data:", sum(clinician_mismatch_dict.values()))
# Out:
# number of patient data: 1208
# number of clinician data: 2454

# %% [markdown]
# number of rows of mismatches and percentages

# %%
print("number of patient data mismatches:", len(patient_mismatch_rows))
print("number of clinician data mismatches:", len(clinician_mismatch_rows))
# Out:
# number of patient data mismatches: 388
# number of clinician data mismatches: 464

# %%
print("percent of rows with patient data mismatches:", len(patient_mismatch_rows)/len(df_mini_pairs)*100)
print("percent of rows with clinician data mismatches:", len(clinician_mismatch_rows)/len(df_mini_pairs)*100)
# Out:
# percent of rows with patient data mismatches: 80.83333333333333
# percent of rows with clinician data mismatches: 96.66666666666667

# %% [markdown]
# printing out mismatch dictionary

# %%
#sort
patient_mismatch_dict = sorted(patient_mismatch_dict.items(), key=lambda  item: item[1], reverse=True)
patient_mismatch_dict
# Out:
# [('Sign or Symptom', 115),
#  ('Body Part, Organ, or Organ Component', 110),
#  ('Disease or Syndrome', 89),
#  ('Body Location or Region', 69),
#  ('Therapeutic or Preventive Procedure', 60),
#  ('Organic Chemical', 59),
#  ('Mental Process', 55),
#  ('Medical Device', 46),
#  ('Health Care Activity', 44),
#  ('Pharmacologic Substance', 41),
#  ('Intellectual Product', 40),
#  ('Finding', 39),
#  ('Organism Function', 39),
#  ('Clinical Attribute', 38),
#  ('Phenomenon or Process', 37),
#  ('Diagnostic Procedure', 37),
#  ('Mental or Behavioral Dysfunction', 32),
#  ('Body Substance', 31),
#  ('Pathologic Function', 30),
#  ('Antibiotic', 28),
#  ('Physiologic Function', 27),
#  ('Laboratory or Test Result', 24),
#  ('Indicator, Reagent, or Diagnostic Aid', 21),
#  ('Laboratory Procedure', 20),
#  ('Injury or Poisoning', 18),
#  ('Amino Acid, Peptide, or Protein', 11),
#  ('Clinical Drug', 10),
#  ('Immunologic Factor', 9),
#  ('Inorganic Chemical', 8),
#  ('Hormone', 7),
#  ('Nucleic Acid, Nucleoside, or Nucleotide', 4),
#  ('Biologically Active Substance', 3),
#  ('Vitamin', 2),
#  ('Neoplastic Process', 2),
#  ('Hazardous or Poisonous Substance', 1),
#  ('Element, Ion, or Isotope', 1),
#  ('Congenital Abnormality', 1)]

# %%
clinician_mismatch_dict = sorted(clinician_mismatch_dict.items(), key=lambda  item: item[1], reverse=True)
clinician_mismatch_dict
# Out:
# [('Mental Process', 229),
#  ('Pharmacologic Substance', 213),
#  ('Therapeutic or Preventive Procedure', 172),
#  ('Health Care Activity', 158),
#  ('Intellectual Product', 154),
#  ('Clinical Attribute', 127),
#  ('Pathologic Function', 115),
#  ('Medical Device', 114),
#  ('Organic Chemical', 113),
#  ('Disease or Syndrome', 110),
#  ('Finding', 89),
#  ('Organism Function', 89),
#  ('Body Part, Organ, or Organ Component', 81),
#  ('Laboratory Procedure', 61),
#  ('Phenomenon or Process', 56),
#  ('Diagnostic Procedure', 55),
#  ('Sign or Symptom', 47),
#  ('Body Substance', 43),
#  ('Laboratory or Test Result', 41),
#  ('Physiologic Function', 40),
#  ('Indicator, Reagent, or Diagnostic Aid', 40),
#  ('Antibiotic', 38),
#  ('Injury or Poisoning', 37),
#  ('Inorganic Chemical', 36),
#  ('Body Location or Region', 31),
#  ('Mental or Behavioral Dysfunction', 28),
#  ('Immunologic Factor', 27),
#  ('Amino Acid, Peptide, or Protein', 21),
#  ('Nucleic Acid, Nucleoside, or Nucleotide', 19),
#  ('Hormone', 13),
#  ('Vitamin', 12),
#  ('Neoplastic Process', 10),
#  ('Hazardous or Poisonous Substance', 9),
#  ('Biologically Active Substance', 9),
#  ('Clinical Drug', 8),
#  ('Element, Ion, or Isotope', 5),
#  ('Manufactured Object', 3),
#  ('Food', 1)]

# %% [markdown]
# ## Looping to extract a set of terms, not entities

# %% [markdown]
# Finding a set of medical terms, not entities. This could be large

# %%
patient_entity_terms = {}
clinician_entity_terms = {}
for index,row in df_mini_pairs.iterrows():
    utterances = row["utterances"]
    
    try:  
        patient =  utterances[0].replace("patient:","").strip()
        patient_results = pipe(patient)
        #loop through the ntities
        for dict in patient_results:
            curr_entity = dict["word"]
            if curr_entity not in patient_entity_terms:
                patient_entity_terms[curr_entity] = 1
            else: 
                patient_entity_terms[curr_entity] = patient_entity_terms[curr_entity] + 1
    except:
        print("no patient mapping at index:", index)
        pass 

    try: 
        clinician = utterances[1].replace("doctor:","").strip()
        clinician_results = pipe(clinician)
        for dict in clinician_results:
            curr_entity = dict["word"]
            if curr_entity not in clinician_entity_terms:
                clinician_entity_terms[curr_entity] = 1
            else: 
                clinician_entity_terms[curr_entity] = clinician_entity_terms[curr_entity] + 1
    except:
        print("no clinican mapping at index:", index)
        pass
# Out:
# no patient mapping at index: 0
# no clinican mapping at index: 0
# no patient mapping at index: 1
# no clinican mapping at index: 1
# no patient mapping at index: 2
# no clinican mapping at index: 2
# no patient mapping at index: 3
# no clinican mapping at index: 3
# no patient mapping at index: 4
# no clinican mapping at index: 4
# no patient mapping at index: 5
# no clinican mapping at index: 5
# no patient mapping at index: 6
# no clinican mapping at index: 6
# no patient mapping at index: 7
# no clinican mapping at index: 7
# no patient mapping at index: 8
# no clinican mapping at index: 8
# no patient mapping at index: 9
# no clinican mapping at index: 9
# no patient mapping at index: 10
# no clinican mapping at index: 10
# no patient mapping at index: 11
# no clinican mapping at index: 11
# no patient mapping at index: 12
# no clinican mapping at index: 12
# no patient mapping at index: 13
# no clinican mapping at index: 13
# no patient mapping at index: 14
# no clinican mapping at index: 14
# no patient mapping at index: 15
# no clinican mapping at index: 15
# no patient mapping at index: 16
# no clinican mapping at index: 16
# no patient mapping at index: 17
# no clinican mapping at index: 17
# no patient mapping at index: 18
# no clinican mapping at index: 18
# no patient mapping at index: 19
# no clinican mapping at index: 19
# no patient mapping at index: 20
# no clinican mapping at index: 20
# no patient mapping at index: 21
# no clinican mapping at index: 21
# no patient mapping at index: 22
# no clinican mapping at index: 22
# no patient mapping at index: 23
# no clinican mapping at index: 23
# no patient mapping at index: 24
# no clinican mapping at index: 24
# no patient mapping at index: 25
# no clinican mapping at index: 25
# no patient mapping at index: 26
# no clinican mapping at index: 26
# no patient mapping at index: 27
# no clinican mapping at index: 27
# no patient mapping at index: 28
# no clinican mapping at index: 28
# no patient mapping at index: 29
# no clinican mapping at index: 29
# no patient mapping at index: 30
# no clinican mapping at index: 30
# no patient mapping at index: 31
# no clinican mapping at index: 31
# no patient mapping at index: 32
# no clinican mapping at index: 32
# no patient mapping at index: 33
# no clinican mapping at index: 33
# no patient mapping at index: 34
# no clinican mapping at index: 34
# no patient mapping at index: 35
# no clinican mapping at index: 35
# no patient mapping at index: 36
# no clinican mapping at index: 36
# no patient mapping at index: 37
# no clinican mapping at index: 37
# no patient mapping at index: 38
# no clinican mapping at index: 38
# no patient mapping at index: 39
# no clinican mapping at index: 39
# no patient mapping at index: 40
# no clinican mapping at index: 40
# no patient mapping at index: 41
# no clinican mapping at index: 41
# no patient mapping at index: 42
# no clinican mapping at index: 42
# no patient mapping at index: 43
# no clinican mapping at index: 43
# no patient mapping at index: 44
# no clinican mapping at index: 44
# no patient mapping at index: 45
# no clinican mapping at index: 45
# no patient mapping at index: 46
# no clinican mapping at index: 46
# no patient mapping at index: 47
# no clinican mapping at index: 47
# no patient mapping at index: 48
# no clinican mapping at index: 48
# no patient mapping at index: 49
# no clinican mapping at index: 49
# no patient mapping at index: 50
# no clinican mapping at index: 50
# no patient mapping at index: 51
# no clinican mapping at index: 51
# no patient mapping at index: 52
# no clinican mapping at index: 52
# no patient mapping at index: 53
# no clinican mapping at index: 53
# no patient mapping at index: 54
# no clinican mapping at index: 54
# no patient mapping at index: 55
# no clinican mapping at index: 55
# no patient mapping at index: 56
# no clinican mapping at index: 56
# no patient mapping at index: 57
# no clinican mapping at index: 57
# no patient mapping at index: 58
# no clinican mapping at index: 58
# no patient mapping at index: 59
# no clinican mapping at index: 59
# no patient mapping at index: 60
# no clinican mapping at index: 60
# no patient mapping at index: 61
# no clinican mapping at index: 61
# no patient mapping at index: 62
# no clinican mapping at index: 62
# no patient mapping at index: 63
# no clinican mapping at index: 63
# no patient mapping at index: 64
# no clinican mapping at index: 64
# no patient mapping at index: 65
# no clinican mapping at index: 65
# no patient mapping at index: 66
# no clinican mapping at index: 66
# no patient mapping at index: 67
# no clinican mapping at index: 67
# no patient mapping at index: 68
# no clinican mapping at index: 68
# no patient mapping at index: 69
# no clinican mapping at index: 69
# no patient mapping at index: 70
# no clinican mapping at index: 70
# no patient mapping at index: 71
# no clinican mapping at index: 71
# no patient mapping at index: 72
# no clinican mapping at index: 72
# no patient mapping at index: 73
# no clinican mapping at index: 73
# no patient mapping at index: 74
# no clinican mapping at index: 74
# no patient mapping at index: 75
# no clinican mapping at index: 75
# no patient mapping at index: 76
# no clinican mapping at index: 76
# no patient mapping at index: 77
# no clinican mapping at index: 77
# no patient mapping at index: 78
# no clinican mapping at index: 78
# no patient mapping at index: 79
# no clinican mapping at index: 79
# no patient mapping at index: 80
# no clinican mapping at index: 80
# no patient mapping at index: 81
# no clinican mapping at index: 81
# no patient mapping at index: 82
# no clinican mapping at index: 82
# no patient mapping at index: 83
# no clinican mapping at index: 83
# no patient mapping at index: 84
# no clinican mapping at index: 84
# no patient mapping at index: 85
# no clinican mapping at index: 85
# no patient mapping at index: 86
# no clinican mapping at index: 86
# no patient mapping at index: 87
# no clinican mapping at index: 87
# no patient mapping at index: 88
# no clinican mapping at index: 88
# no patient mapping at index: 89
# no clinican mapping at index: 89
# no patient mapping at index: 90
# no clinican mapping at index: 90
# no patient mapping at index: 91
# no clinican mapping at index: 91
# no patient mapping at index: 92
# no clinican mapping at index: 92
# no patient mapping at index: 93
# no clinican mapping at index: 93
# no patient mapping at index: 94
# no clinican mapping at index: 94
# no patient mapping at index: 95
# no clinican mapping at index: 95
# no patient mapping at index: 96
# no clinican mapping at index: 96
# no patient mapping at index: 97
# no clinican mapping at index: 97
# no patient mapping at index: 98
# no clinican mapping at index: 98
# no patient mapping at index: 99
# no clinican mapping at index: 99
# no patient mapping at index: 100
# no clinican mapping at index: 100
# no patient mapping at index: 101
# no clinican mapping at index: 101
# no patient mapping at index: 102
# no clinican mapping at index: 102
# no patient mapping at index: 103
# no clinican mapping at index: 103
# no patient mapping at index: 104
# no clinican mapping at index: 104
# no patient mapping at index: 105
# no clinican mapping at index: 105
# no patient mapping at index: 106
# no clinican mapping at index: 106
# no patient mapping at index: 107
# no clinican mapping at index: 107
# no patient mapping at index: 108
# no clinican mapping at index: 108
# no patient mapping at index: 109
# no clinican mapping at index: 109
# no patient mapping at index: 110
# no clinican mapping at index: 110
# no patient mapping at index: 111
# no clinican mapping at index: 111
# no patient mapping at index: 112
# no clinican mapping at index: 112
# no patient mapping at index: 113
# no clinican mapping at index: 113
# no patient mapping at index: 114
# no clinican mapping at index: 114
# no patient mapping at index: 115
# no clinican mapping at index: 115
# no patient mapping at index: 116
# no clinican mapping at index: 116
# no patient mapping at index: 117
# no clinican mapping at index: 117
# no patient mapping at index: 118
# no clinican mapping at index: 118
# no patient mapping at index: 119
# no clinican mapping at index: 119
# no patient mapping at index: 120
# no clinican mapping at index: 120
# no patient mapping at index: 121
# no clinican mapping at index: 121
# no patient mapping at index: 122
# no clinican mapping at index: 122
# no patient mapping at index: 123
# no clinican mapping at index: 123
# no patient mapping at index: 124
# no clinican mapping at index: 124
# no patient mapping at index: 125
# no clinican mapping at index: 125
# no patient mapping at index: 126
# no clinican mapping at index: 126
# no patient mapping at index: 127
# no clinican mapping at index: 127
# no patient mapping at index: 128
# no clinican mapping at index: 128
# no patient mapping at index: 129
# no clinican mapping at index: 129
# no patient mapping at index: 130
# no clinican mapping at index: 130
# no patient mapping at index: 131
# no clinican mapping at index: 131
# no patient mapping at index: 132
# no clinican mapping at index: 132
# no patient mapping at index: 133
# no clinican mapping at index: 133
# no patient mapping at index: 134
# no clinican mapping at index: 134
# no patient mapping at index: 135
# no clinican mapping at index: 135
# no patient mapping at index: 136
# no clinican mapping at index: 136
# no patient mapping at index: 137
# no clinican mapping at index: 137
# no patient mapping at index: 138
# no clinican mapping at index: 138
# no patient mapping at index: 139
# no clinican mapping at index: 139
# no patient mapping at index: 140
# no clinican mapping at index: 140
# no patient mapping at index: 141
# no clinican mapping at index: 141
# no patient mapping at index: 142
# no clinican mapping at index: 142
# no patient mapping at index: 143
# no clinican mapping at index: 143
# no patient mapping at index: 144
# no clinican mapping at index: 144
# no patient mapping at index: 145
# no clinican mapping at index: 145
# no patient mapping at index: 146
# no clinican mapping at index: 146
# no patient mapping at index: 147
# no clinican mapping at index: 147
# no patient mapping at index: 148
# no clinican mapping at index: 148
# no patient mapping at index: 149
# no clinican mapping at index: 149
# no patient mapping at index: 150
# no clinican mapping at index: 150
# no patient mapping at index: 151
# no clinican mapping at index: 151
# no patient mapping at index: 152
# no clinican mapping at index: 152
# no patient mapping at index: 153
# no clinican mapping at index: 153
# no patient mapping at index: 154
# no clinican mapping at index: 154
# no patient mapping at index: 155
# no clinican mapping at index: 155
# no patient mapping at index: 156
# no clinican mapping at index: 156
# no patient mapping at index: 157
# no clinican mapping at index: 157
# no patient mapping at index: 158
# no clinican mapping at index: 158
# no patient mapping at index: 159
# no clinican mapping at index: 159
# no patient mapping at index: 160
# no clinican mapping at index: 160
# no patient mapping at index: 161
# no clinican mapping at index: 161
# no patient mapping at index: 162
# no clinican mapping at index: 162
# no patient mapping at index: 163
# no clinican mapping at index: 163
# no patient mapping at index: 164
# no clinican mapping at index: 164
# no patient mapping at index: 165
# no clinican mapping at index: 165
# no patient mapping at index: 166
# no clinican mapping at index: 166
# no patient mapping at index: 167
# no clinican mapping at index: 167
# no patient mapping at index: 168
# no clinican mapping at index: 168
# no patient mapping at index: 169
# no clinican mapping at index: 169
# no patient mapping at index: 170
# no clinican mapping at index: 170
# no patient mapping at index: 171
# no clinican mapping at index: 171
# no patient mapping at index: 172
# no clinican mapping at index: 172
# no patient mapping at index: 173
# no clinican mapping at index: 173
# no patient mapping at index: 174
# no clinican mapping at index: 174
# no patient mapping at index: 175
# no clinican mapping at index: 175
# no patient mapping at index: 176
# no clinican mapping at index: 176
# no patient mapping at index: 177
# no clinican mapping at index: 177
# no patient mapping at index: 178
# no clinican mapping at index: 178
# no patient mapping at index: 179
# no clinican mapping at index: 179
# no patient mapping at index: 180
# no clinican mapping at index: 180
# no patient mapping at index: 181
# no clinican mapping at index: 181
# no patient mapping at index: 182
# no clinican mapping at index: 182
# no patient mapping at index: 183
# no clinican mapping at index: 183
# no patient mapping at index: 184
# no clinican mapping at index: 184
# no patient mapping at index: 185
# no clinican mapping at index: 185
# no patient mapping at index: 186
# no clinican mapping at index: 186
# no patient mapping at index: 187
# no clinican mapping at index: 187
# no patient mapping at index: 188
# no clinican mapping at index: 188
# no patient mapping at index: 189
# no clinican mapping at index: 189
# no patient mapping at index: 190
# no clinican mapping at index: 190
# no patient mapping at index: 191
# no clinican mapping at index: 191
# no patient mapping at index: 192
# no clinican mapping at index: 192
# no patient mapping at index: 193
# no clinican mapping at index: 193
# no patient mapping at index: 194
# no clinican mapping at index: 194
# no patient mapping at index: 195
# no clinican mapping at index: 195
# no patient mapping at index: 196
# no clinican mapping at index: 196
# no patient mapping at index: 197
# no clinican mapping at index: 197
# no patient mapping at index: 198
# no clinican mapping at index: 198
# no patient mapping at index: 199
# no clinican mapping at index: 199
# no patient mapping at index: 200
# no clinican mapping at index: 200
# no patient mapping at index: 201
# no clinican mapping at index: 201
# no patient mapping at index: 202
# no clinican mapping at index: 202
# no patient mapping at index: 203
# no clinican mapping at index: 203
# no patient mapping at index: 204
# no clinican mapping at index: 204
# no patient mapping at index: 205
# no clinican mapping at index: 205
# no patient mapping at index: 206
# no clinican mapping at index: 206
# no patient mapping at index: 207
# no clinican mapping at index: 207
# no patient mapping at index: 208
# no clinican mapping at index: 208
# no patient mapping at index: 209
# no clinican mapping at index: 209
# no patient mapping at index: 210
# no clinican mapping at index: 210
# no patient mapping at index: 211
# no clinican mapping at index: 211
# no patient mapping at index: 212
# no clinican mapping at index: 212
# no patient mapping at index: 213
# no clinican mapping at index: 213
# no patient mapping at index: 214
# no clinican mapping at index: 214
# no patient mapping at index: 215
# no clinican mapping at index: 215
# no patient mapping at index: 216
# no clinican mapping at index: 216
# no patient mapping at index: 217
# no clinican mapping at index: 217
# no patient mapping at index: 218
# no clinican mapping at index: 218
# no patient mapping at index: 219
# no clinican mapping at index: 219
# no patient mapping at index: 220
# no clinican mapping at index: 220
# no patient mapping at index: 221
# no clinican mapping at index: 221
# no patient mapping at index: 222
# no clinican mapping at index: 222
# no patient mapping at index: 223
# no clinican mapping at index: 223
# no patient mapping at index: 224
# no clinican mapping at index: 224
# no patient mapping at index: 225
# no clinican mapping at index: 225
# no patient mapping at index: 226
# no clinican mapping at index: 226
# no patient mapping at index: 227
# no clinican mapping at index: 227
# no patient mapping at index: 228
# no clinican mapping at index: 228
# no patient mapping at index: 229
# no clinican mapping at index: 229
# no patient mapping at index: 230
# no clinican mapping at index: 230
# no patient mapping at index: 231
# no clinican mapping at index: 231
# no patient mapping at index: 232
# no clinican mapping at index: 232
# no patient mapping at index: 233
# no clinican mapping at index: 233
# no patient mapping at index: 234
# no clinican mapping at index: 234
# no patient mapping at index: 235
# no clinican mapping at index: 235
# no patient mapping at index: 236
# no clinican mapping at index: 236
# no patient mapping at index: 237
# no clinican mapping at index: 237
# no patient mapping at index: 238
# no clinican mapping at index: 238
# no patient mapping at index: 239
# no clinican mapping at index: 239
# no patient mapping at index: 240
# no clinican mapping at index: 240
# no patient mapping at index: 241
# no clinican mapping at index: 241
# no patient mapping at index: 242
# no clinican mapping at index: 242
# no patient mapping at index: 243
# no clinican mapping at index: 243
# no patient mapping at index: 244
# no clinican mapping at index: 244
# no patient mapping at index: 245
# no clinican mapping at index: 245
# no patient mapping at index: 246
# no clinican mapping at index: 246
# no patient mapping at index: 247
# no clinican mapping at index: 247
# no patient mapping at index: 248
# no clinican mapping at index: 248
# no patient mapping at index: 249
# no clinican mapping at index: 249
# no patient mapping at index: 250
# no clinican mapping at index: 250
# no patient mapping at index: 251
# no clinican mapping at index: 251
# no patient mapping at index: 252
# no clinican mapping at index: 252
# no patient mapping at index: 253
# no clinican mapping at index: 253
# no patient mapping at index: 254
# no clinican mapping at index: 254
# no patient mapping at index: 255
# no clinican mapping at index: 255
# no patient mapping at index: 256
# no clinican mapping at index: 256
# no patient mapping at index: 257
# no clinican mapping at index: 257
# no patient mapping at index: 258
# no clinican mapping at index: 258
# no patient mapping at index: 259
# no clinican mapping at index: 259
# no patient mapping at index: 260
# no clinican mapping at index: 260
# no patient mapping at index: 261
# no clinican mapping at index: 261
# no patient mapping at index: 262
# no clinican mapping at index: 262
# no patient mapping at index: 263
# no clinican mapping at index: 263
# no patient mapping at index: 264
# no clinican mapping at index: 264
# no patient mapping at index: 265
# no clinican mapping at index: 265
# no patient mapping at index: 266
# no clinican mapping at index: 266
# no patient mapping at index: 267
# no clinican mapping at index: 267
# no patient mapping at index: 268
# no clinican mapping at index: 268
# no patient mapping at index: 269
# no clinican mapping at index: 269
# no patient mapping at index: 270
# no clinican mapping at index: 270
# no patient mapping at index: 271
# no clinican mapping at index: 271
# no patient mapping at index: 272
# no clinican mapping at index: 272
# no patient mapping at index: 273
# no clinican mapping at index: 273
# no patient mapping at index: 274
# no clinican mapping at index: 274
# no patient mapping at index: 275
# no clinican mapping at index: 275
# no patient mapping at index: 276
# no clinican mapping at index: 276
# no patient mapping at index: 277
# no clinican mapping at index: 277
# no patient mapping at index: 278
# no clinican mapping at index: 278
# no patient mapping at index: 279
# no clinican mapping at index: 279
# no patient mapping at index: 280
# no clinican mapping at index: 280
# no patient mapping at index: 281
# no clinican mapping at index: 281
# no patient mapping at index: 282
# no clinican mapping at index: 282
# no patient mapping at index: 283
# no clinican mapping at index: 283
# no patient mapping at index: 284
# no clinican mapping at index: 284
# no patient mapping at index: 285
# no clinican mapping at index: 285
# no patient mapping at index: 286
# no clinican mapping at index: 286
# no patient mapping at index: 287
# no clinican mapping at index: 287
# no patient mapping at index: 288
# no clinican mapping at index: 288
# no patient mapping at index: 289
# no clinican mapping at index: 289
# no patient mapping at index: 290
# no clinican mapping at index: 290
# no patient mapping at index: 291
# no clinican mapping at index: 291
# no patient mapping at index: 292
# no clinican mapping at index: 292
# no patient mapping at index: 293
# no clinican mapping at index: 293
# no patient mapping at index: 294
# no clinican mapping at index: 294
# no patient mapping at index: 295
# no clinican mapping at index: 295
# no patient mapping at index: 296
# no clinican mapping at index: 296
# no patient mapping at index: 297
# no clinican mapping at index: 297
# no patient mapping at index: 298
# no clinican mapping at index: 298
# no patient mapping at index: 299
# no clinican mapping at index: 299
# no patient mapping at index: 300
# no clinican mapping at index: 300
# no patient mapping at index: 301
# no clinican mapping at index: 301
# no patient mapping at index: 302
# no clinican mapping at index: 302
# no patient mapping at index: 303
# no clinican mapping at index: 303
# no patient mapping at index: 304
# no clinican mapping at index: 304
# no patient mapping at index: 305
# no clinican mapping at index: 305
# no patient mapping at index: 306
# no clinican mapping at index: 306
# no patient mapping at index: 307
# no clinican mapping at index: 307
# no patient mapping at index: 308
# no clinican mapping at index: 308
# no patient mapping at index: 309
# no clinican mapping at index: 309
# no patient mapping at index: 310
# no clinican mapping at index: 310
# no patient mapping at index: 311
# no clinican mapping at index: 311
# no patient mapping at index: 312
# no clinican mapping at index: 312
# no patient mapping at index: 313
# no clinican mapping at index: 313
# no patient mapping at index: 314
# no clinican mapping at index: 314
# no patient mapping at index: 315
# no clinican mapping at index: 315
# no patient mapping at index: 316
# no clinican mapping at index: 316
# no patient mapping at index: 317
# no clinican mapping at index: 317
# no patient mapping at index: 318
# no clinican mapping at index: 318
# no patient mapping at index: 319
# no clinican mapping at index: 319
# no patient mapping at index: 320
# no clinican mapping at index: 320
# no patient mapping at index: 321
# no clinican mapping at index: 321
# no patient mapping at index: 322
# no clinican mapping at index: 322
# no patient mapping at index: 323
# no clinican mapping at index: 323
# no patient mapping at index: 324
# no clinican mapping at index: 324
# no patient mapping at index: 325
# no clinican mapping at index: 325
# no patient mapping at index: 326
# no clinican mapping at index: 326
# no patient mapping at index: 327
# no clinican mapping at index: 327
# no patient mapping at index: 328
# no clinican mapping at index: 328
# no patient mapping at index: 329
# no clinican mapping at index: 329
# no patient mapping at index: 330
# no clinican mapping at index: 330
# no patient mapping at index: 331
# no clinican mapping at index: 331
# no patient mapping at index: 332
# no clinican mapping at index: 332
# no patient mapping at index: 333
# no clinican mapping at index: 333
# no patient mapping at index: 334
# no clinican mapping at index: 334
# no patient mapping at index: 335
# no clinican mapping at index: 335
# no patient mapping at index: 336
# no clinican mapping at index: 336
# no patient mapping at index: 337
# no clinican mapping at index: 337
# no patient mapping at index: 338
# no clinican mapping at index: 338
# no patient mapping at index: 339
# no clinican mapping at index: 339
# no patient mapping at index: 340
# no clinican mapping at index: 340
# no patient mapping at index: 341
# no clinican mapping at index: 341
# no patient mapping at index: 342
# no clinican mapping at index: 342
# no patient mapping at index: 343
# no clinican mapping at index: 343
# no patient mapping at index: 344
# no clinican mapping at index: 344
# no patient mapping at index: 345
# no clinican mapping at index: 345
# no patient mapping at index: 346
# no clinican mapping at index: 346
# no patient mapping at index: 347
# no clinican mapping at index: 347
# no patient mapping at index: 348
# no clinican mapping at index: 348
# no patient mapping at index: 349
# no clinican mapping at index: 349
# no patient mapping at index: 350
# no clinican mapping at index: 350
# no patient mapping at index: 351
# no clinican mapping at index: 351
# no patient mapping at index: 352
# no clinican mapping at index: 352
# no patient mapping at index: 353
# no clinican mapping at index: 353
# no patient mapping at index: 354
# no clinican mapping at index: 354
# no patient mapping at index: 355
# no clinican mapping at index: 355
# no patient mapping at index: 356
# no clinican mapping at index: 356
# no patient mapping at index: 357
# no clinican mapping at index: 357
# no patient mapping at index: 358
# no clinican mapping at index: 358
# no patient mapping at index: 359
# no clinican mapping at index: 359
# no patient mapping at index: 360
# no clinican mapping at index: 360
# no patient mapping at index: 361
# no clinican mapping at index: 361
# no patient mapping at index: 362
# no clinican mapping at index: 362
# no patient mapping at index: 363
# no clinican mapping at index: 363
# no patient mapping at index: 364
# no clinican mapping at index: 364
# no patient mapping at index: 365
# no clinican mapping at index: 365
# no patient mapping at index: 366
# no clinican mapping at index: 366
# no patient mapping at index: 367
# no clinican mapping at index: 367
# no patient mapping at index: 368
# no clinican mapping at index: 368
# no patient mapping at index: 369
# no clinican mapping at index: 369
# no patient mapping at index: 370
# no clinican mapping at index: 370
# no patient mapping at index: 371
# no clinican mapping at index: 371
# no patient mapping at index: 372
# no clinican mapping at index: 372
# no patient mapping at index: 373
# no clinican mapping at index: 373
# no patient mapping at index: 374
# no clinican mapping at index: 374
# no patient mapping at index: 375
# no clinican mapping at index: 375
# no patient mapping at index: 376
# no clinican mapping at index: 376
# no patient mapping at index: 377
# no clinican mapping at index: 377
# no patient mapping at index: 378
# no clinican mapping at index: 378
# no patient mapping at index: 379
# no clinican mapping at index: 379
# no patient mapping at index: 380
# no clinican mapping at index: 380
# no patient mapping at index: 381
# no clinican mapping at index: 381
# no patient mapping at index: 382
# no clinican mapping at index: 382
# no patient mapping at index: 383
# no clinican mapping at index: 383
# no patient mapping at index: 384
# no clinican mapping at index: 384
# no patient mapping at index: 385
# no clinican mapping at index: 385
# no patient mapping at index: 386
# no clinican mapping at index: 386
# no patient mapping at index: 387
# no clinican mapping at index: 387
# no patient mapping at index: 388
# no clinican mapping at index: 388
# no patient mapping at index: 389
# no clinican mapping at index: 389
# no patient mapping at index: 390
# no clinican mapping at index: 390
# no patient mapping at index: 391
# no clinican mapping at index: 391
# no patient mapping at index: 392
# no clinican mapping at index: 392
# no patient mapping at index: 393
# no clinican mapping at index: 393
# no patient mapping at index: 394
# no clinican mapping at index: 394
# no patient mapping at index: 395
# no clinican mapping at index: 395
# no patient mapping at index: 396
# no clinican mapping at index: 396
# no patient mapping at index: 397
# no clinican mapping at index: 397
# no patient mapping at index: 398
# no clinican mapping at index: 398
# no patient mapping at index: 399
# no clinican mapping at index: 399
# no patient mapping at index: 400
# no clinican mapping at index: 400
# no patient mapping at index: 401
# no clinican mapping at index: 401
# no patient mapping at index: 402
# no clinican mapping at index: 402
# no patient mapping at index: 403
# no clinican mapping at index: 403
# no patient mapping at index: 404
# no clinican mapping at index: 404
# no patient mapping at index: 405
# no clinican mapping at index: 405
# no patient mapping at index: 406
# no clinican mapping at index: 406
# no patient mapping at index: 407
# no clinican mapping at index: 407
# no patient mapping at index: 408
# no clinican mapping at index: 408
# no patient mapping at index: 409
# no clinican mapping at index: 409
# no patient mapping at index: 410
# no clinican mapping at index: 410
# no patient mapping at index: 411
# no clinican mapping at index: 411
# no patient mapping at index: 412
# no clinican mapping at index: 412
# no patient mapping at index: 413
# no clinican mapping at index: 413
# no patient mapping at index: 414
# no clinican mapping at index: 414
# no patient mapping at index: 415
# no clinican mapping at index: 415
# no patient mapping at index: 416
# no clinican mapping at index: 416
# no patient mapping at index: 417
# no clinican mapping at index: 417
# no patient mapping at index: 418
# no clinican mapping at index: 418
# no patient mapping at index: 419
# no clinican mapping at index: 419
# no patient mapping at index: 420
# no clinican mapping at index: 420
# no patient mapping at index: 421
# no clinican mapping at index: 421
# no patient mapping at index: 422
# no clinican mapping at index: 422
# no patient mapping at index: 423
# no clinican mapping at index: 423
# no patient mapping at index: 424
# no clinican mapping at index: 424
# no patient mapping at index: 425
# no clinican mapping at index: 425
# no patient mapping at index: 426
# no clinican mapping at index: 426
# no patient mapping at index: 427
# no clinican mapping at index: 427
# no patient mapping at index: 428
# no clinican mapping at index: 428
# no patient mapping at index: 429
# no clinican mapping at index: 429
# no patient mapping at index: 430
# no clinican mapping at index: 430
# no patient mapping at index: 431
# no clinican mapping at index: 431
# no patient mapping at index: 432
# no clinican mapping at index: 432
# no patient mapping at index: 433
# no clinican mapping at index: 433
# no patient mapping at index: 434
# no clinican mapping at index: 434
# no patient mapping at index: 435
# no clinican mapping at index: 435
# no patient mapping at index: 436
# no clinican mapping at index: 436
# no patient mapping at index: 437
# no clinican mapping at index: 437
# no patient mapping at index: 438
# no clinican mapping at index: 438
# no patient mapping at index: 439
# no clinican mapping at index: 439
# no patient mapping at index: 440
# no clinican mapping at index: 440
# no patient mapping at index: 441
# no clinican mapping at index: 441
# no patient mapping at index: 442
# no clinican mapping at index: 442
# no patient mapping at index: 443
# no clinican mapping at index: 443
# no patient mapping at index: 444
# no clinican mapping at index: 444
# no patient mapping at index: 445
# no clinican mapping at index: 445
# no patient mapping at index: 446
# no clinican mapping at index: 446
# no patient mapping at index: 447
# no clinican mapping at index: 447
# no patient mapping at index: 448
# no clinican mapping at index: 448
# no patient mapping at index: 449
# no clinican mapping at index: 449
# no patient mapping at index: 450
# no clinican mapping at index: 450
# no patient mapping at index: 451
# no clinican mapping at index: 451
# no patient mapping at index: 452
# no clinican mapping at index: 452
# no patient mapping at index: 453
# no clinican mapping at index: 453
# no patient mapping at index: 454
# no clinican mapping at index: 454
# no patient mapping at index: 455
# no clinican mapping at index: 455
# no patient mapping at index: 456
# no clinican mapping at index: 456
# no patient mapping at index: 457
# no clinican mapping at index: 457
# no patient mapping at index: 458
# no clinican mapping at index: 458
# no patient mapping at index: 459
# no clinican mapping at index: 459
# no patient mapping at index: 460
# no clinican mapping at index: 460
# no patient mapping at index: 461
# no clinican mapping at index: 461
# no patient mapping at index: 462
# no clinican mapping at index: 462
# no patient mapping at index: 463
# no clinican mapping at index: 463
# no patient mapping at index: 464
# no clinican mapping at index: 464
# no patient mapping at index: 465
# no clinican mapping at index: 465
# no patient mapping at index: 466
# no clinican mapping at index: 466
# no patient mapping at index: 467
# no clinican mapping at index: 467
# no patient mapping at index: 468
# no clinican mapping at index: 468
# no patient mapping at index: 469
# no clinican mapping at index: 469
# no patient mapping at index: 470
# no clinican mapping at index: 470
# no patient mapping at index: 471
# no clinican mapping at index: 471
# no patient mapping at index: 472
# no clinican mapping at index: 472
# no patient mapping at index: 473
# no clinican mapping at index: 473
# no patient mapping at index: 474
# no clinican mapping at index: 474
# no patient mapping at index: 475
# no clinican mapping at index: 475
# no patient mapping at index: 476
# no clinican mapping at index: 476
# no patient mapping at index: 477
# no clinican mapping at index: 477
# no patient mapping at index: 478
# no clinican mapping at index: 478
# no patient mapping at index: 479
# no clinican mapping at index: 479

# %% [markdown]
# Printing out side of patient terms and clincians terms and using set similarity

# %%
print(len(patient_entity_terms))
patient_entity_terms
# Out:
# 0
# {}

# %%
print(len(clinician_entity_terms))
clinician_entity_terms
# Out:
# 0
# {}

# %% [markdown]
# computing jaccard similarity

# %%
pghd_set = set(patient_entity_terms.keys())
clinician_set = set(clinician_entity_terms.keys())

jaccard = len(pghd_set & clinician_set) / len(pghd_set | clinician_set)
print(f"Conceptual Overlap (Jaccard): {jaccard:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-32-b5122b246448> in <module>
#       2 clinician_set = set(clinician_entity_terms.keys())
#       3
# ----> 4 jaccard = len(pghd_set & clinician_set) / len(pghd_set | clinician_set)
#       5 print(f"Conceptual Overlap (Jaccard): {jaccard:.3f}")
#
# ZeroDivisionError: division by zero

# %%
print(pghd_set-clinician_set)

# %% [markdown]
# ## future:
#
# Showing (through concepts per 100 words):
# QuickUMLS ontology has beeter coveration
